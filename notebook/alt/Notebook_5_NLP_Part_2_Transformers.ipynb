# %% [markdown]
# # Notebook 5 – NLP Part 2 (Transformers)
#
# Moderne NLP-Demo mit Transformers (Inferenz, optional Mini-Evaluation).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## Setup Transformers (optional)
#
# Auf Kaggle meist unkompliziert.

# %%
# Optional:
# !pip -q install transformers accelerate

# %% [markdown]
# ## Textklassifikation per Pipeline (optional)

# %%
# Optional:
# from transformers import pipeline
# clf = pipeline("sentiment-analysis")
# clf(["Das Produkt ist hervorragend.", "Der Support war leider sehr schlecht."])

# %% [markdown]
# ## Named Entity Recognition (optional)

# %%
# Optional:
# from transformers import pipeline
# ner = pipeline("ner", aggregation_strategy="simple")
# ner("Morgen trifft Bill Gates zwei Freunde in Berlin.")

# %% [markdown]
# ## Mini-Evaluation (optional)
#
# Kleines Set anlegen und F1 berechnen.

# %%
# TODO
